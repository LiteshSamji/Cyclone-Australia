# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("data/IDCKMSTM0S.csv", na_values=' ')
df
# Out:
#            NAME DISTURBANCE_ID                TM TYPE  DATA_SRC  SURFACE_CODE  \
# 0      unnamed    AU190607_01U  17/01/1907 23:00    T       NaN           1.0
# 1      unnamed    AU190607_01U  18/01/1907 23:00    T       NaN           3.0
# 2      unnamed    AU190607_01U  19/01/1907 23:00    T       NaN           2.0
# 3      unnamed    AU190607_01U  20/01/1907 23:00    T       NaN           2.0
# 4      unnamed    AU190607_01U  21/01/1907 23:00    T       NaN           4.0
# ...         ...            ...               ...  ...       ...           ...
# 28300   Odette    AU202021_23U   9/04/2021 12:00    D       NaN           NaN
# 28301   Odette    AU202021_23U   9/04/2021 18:00    D       NaN           NaN
# 28302   Odette    AU202021_23U   10/04/2021 0:00    D       NaN           NaN
# 28303   Odette    AU202021_23U   10/04/2021 6:00    D       NaN           NaN
# 28304   Odette    AU202021_23U  10/04/2021 12:00    D       NaN           NaN
#
#        CYC_TYPE   LAT    LON  POSITION_METHOD  ...  MAX_REP_SWL_PER  \
# 0           NaN -13.0  146.5              NaN  ...              NaN
# 1           NaN -15.0  145.0              NaN  ...              NaN
# 2           NaN -14.0  143.0              NaN  ...              NaN
# 3           NaN -13.5  142.0              NaN  ...              NaN
# 4           NaN -15.6  141.5              NaN  ...              NaN
# ...         ...   ...    ...              ...  ...              ...
# 28300       NaN -15.8  110.9              NaN  ...              NaN
# 28301       NaN -17.1  112.2              NaN  ...              NaN
# 28302       NaN -18.9  112.8              NaN  ...              NaN
# 28303       NaN -21.0  112.8              NaN  ...              NaN
# 28304       NaN -23.5  111.9              NaN  ...              NaN
#
#        MAX_REP_SWL_METHOD  MAX_REP_SWL_LON  MAX_REP_SWL_LAT  \
# 0                     NaN              NaN              NaN
# 1                     NaN              NaN              NaN
# 2                     NaN              NaN              NaN
# 3                     NaN              NaN              NaN
# 4                     NaN              NaN              NaN
# ...                   ...              ...              ...
# 28300                 NaN              NaN              NaN
# 28301                 NaN              NaN              NaN
# 28302                 NaN              NaN              NaN
# 28303                 NaN              NaN              NaN
# 28304                 NaN              NaN              NaN
#
#        MAX_REP_TIDE_ANOM  MAX_REP_TIDE_ANOM_UNCERTAINTY  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN                            NaN
# 4                    NaN                            NaN
# ...                  ...                            ...
# 28300                NaN                            NaN
# 28301                NaN                            NaN
# 28302                NaN                            NaN
# 28303                NaN                            NaN
# 28304                NaN                            NaN
#
#        MAX_REP_TIDE_ANOM_METHOD  MAX_REP_TIDE_ANOM_LON  MAX_REP_TIDE_ANOM_LAT  \
# 0                           NaN                    NaN                    NaN
# 1                           NaN                    NaN                    NaN
# 2                           NaN                    NaN                    NaN
# 3                           NaN                    NaN                    NaN
# 4                           NaN                    NaN                    NaN
# ...                         ...                    ...                    ...
# 28300                       NaN                    NaN                    NaN
# 28301                       NaN                    NaN                    NaN
# 28302                       NaN                    NaN                    NaN
# 28303                       NaN                    NaN                    NaN
# 28304                       NaN                    NaN                    NaN
#
#                                COMMENT
# 0      Imported from CYCARD; June 2009
# 1      Imported from CYCARD; June 2009
# 2      Imported from CYCARD; June 2009
# 3      Imported from CYCARD; June 2009
# 4      Imported from CYCARD; June 2009
# ...                                ...
# 28300                              NaN
# 28301                              NaN
# 28302                              NaN
# 28303                              NaN
# 28304                              NaN
#
# [28305 rows x 79 columns]

# %%
# Extract data range 1990 onwards
data['TM'] = pd.to_datetime(data['TM'], format='%d/%m/%Y %H:%M')
data_1990 = data.loc[data["TM"] >= "01-01-1990"]
data_1990
# Out:
#           NAME DISTURBANCE_ID                  TM TYPE  DATA_SRC  \
# 16331  ROSITA    AU198990_03U 1990-01-04 18:00:00    T       2.0
# 16332  ROSITA    AU198990_03U 1990-01-05 00:00:00    T       2.0
# 16333  ROSITA    AU198990_03U 1990-01-05 06:00:00    T       2.0
# 16334  ROSITA    AU198990_03U 1990-01-05 12:00:00    T       2.0
# 16335  ROSITA    AU198990_03U 1990-01-05 18:00:00    T       2.0
# ...        ...            ...                 ...  ...       ...
# 28300  Odette    AU202021_23U 2021-04-09 12:00:00    D       NaN
# 28301  Odette    AU202021_23U 2021-04-09 18:00:00    D       NaN
# 28302  Odette    AU202021_23U 2021-04-10 00:00:00    D       NaN
# 28303  Odette    AU202021_23U 2021-04-10 06:00:00    D       NaN
# 28304  Odette    AU202021_23U 2021-04-10 12:00:00    D       NaN
#
#        SURFACE_CODE  CYC_TYPE   LAT    LON  POSITION_METHOD  ...  \
# 16331           1.0      20.0 -12.7  111.7              3.0  ...
# 16332           1.0      20.0 -12.8  110.6              3.0  ...
# 16333           1.0      20.0 -12.9  109.8              3.0  ...
# 16334           1.0      20.0 -13.0  108.5              3.0  ...
# 16335           1.0      20.0 -13.2  107.0              3.0  ...
# ...             ...       ...   ...    ...              ...  ...
# 28300           NaN       NaN -15.8  110.9              NaN  ...
# 28301           NaN       NaN -17.1  112.2              NaN  ...
# 28302           NaN       NaN -18.9  112.8              NaN  ...
# 28303           NaN       NaN -21.0  112.8              NaN  ...
# 28304           NaN       NaN -23.5  111.9              NaN  ...
#
#        MAX_REP_SWL_PER  MAX_REP_SWL_METHOD  MAX_REP_SWL_LON  MAX_REP_SWL_LAT  \
# 16331              NaN                 NaN              NaN              NaN
# 16332              NaN                 NaN              NaN              NaN
# 16333              NaN                 NaN              NaN              NaN
# 16334             10.0                 1.0            106.7            -13.6
# 16335              NaN                 NaN              NaN              NaN
# ...                ...                 ...              ...              ...
# 28300              NaN                 NaN              NaN              NaN
# 28301              NaN                 NaN              NaN              NaN
# 28302              NaN                 NaN              NaN              NaN
# 28303              NaN                 NaN              NaN              NaN
# 28304              NaN                 NaN              NaN              NaN
#
#        MAX_REP_TIDE_ANOM  MAX_REP_TIDE_ANOM_UNCERTAINTY  \
# 16331                NaN                            NaN
# 16332                NaN                            NaN
# 16333                NaN                            NaN
# 16334                NaN                            NaN
# 16335                NaN                            NaN
# ...                  ...                            ...
# 28300                NaN                            NaN
# 28301                NaN                            NaN
# 28302                NaN                            NaN
# 28303                NaN                            NaN
# 28304                NaN                            NaN
#
#        MAX_REP_TIDE_ANOM_METHOD  MAX_REP_TIDE_ANOM_LON  MAX_REP_TIDE_ANOM_LAT  \
# 16331                       NaN                    NaN                    NaN
# 16332                       NaN                    NaN                    NaN
# 16333                       NaN                    NaN                    NaN
# 16334                       NaN                    NaN                    NaN
# 16335                       NaN                    NaN                    NaN
# ...                         ...                    ...                    ...
# 28300                       NaN                    NaN                    NaN
# 28301                       NaN                    NaN                    NaN
# 28302                       NaN                    NaN                    NaN
# 28303                       NaN                    NaN                    NaN
# 28304                       NaN                    NaN                    NaN
#
#        COMMENT
# 16331      NaN
# 16332      NaN
# 16333      NaN
# 16334      NaN
# 16335      NaN
# ...        ...
# 28300      NaN
# 28301      NaN
# 28302      NaN
# 28303      NaN
# 28304      NaN
#
# [11972 rows x 79 columns]

# %%
data_df = data_1990[["NAME","TM", "TYPE","DATA_SRC", "SURFACE_CODE", "CYC_TYPE", "LAT","LON","CENTRAL_PRES",
           "MAX_WIND_SPD"]]
data_df["NAME"]=data_df["NAME"].apply(lambda x: x.strip().title())
data_df["NAME"]
# Out:
# C:\Users\Lites\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 16331    Rosita
# 16332    Rosita
# 16333    Rosita
# 16334    Rosita
# 16335    Rosita
#           ...
# 28300    Odette
# 28301    Odette
# 28302    Odette
# 28303    Odette
# 28304    Odette
# Name: NAME, Length: 11972, dtype: object

# %%
#Create a copy
df_data = data_df.copy()

# %%
data_df = data_df.dropna()
data_df.shape
# Out:
# (8934, 10)

# %%
data_df.to_csv("data/Cyclone_1990_clean.csv", sep= ",",header=True, index=False)

# %% [markdown]
# # Create a csv file for ML with Wind Direction data

# %%
data['TM'] = pd.to_datetime(data['TM'], format='%d/%m/%Y %H:%M')
data
# Out:
#            NAME DISTURBANCE_ID                  TM TYPE  DATA_SRC  \
# 0      unnamed    AU190607_01U 1907-01-17 23:00:00    T       NaN
# 1      unnamed    AU190607_01U 1907-01-18 23:00:00    T       NaN
# 2      unnamed    AU190607_01U 1907-01-19 23:00:00    T       NaN
# 3      unnamed    AU190607_01U 1907-01-20 23:00:00    T       NaN
# 4      unnamed    AU190607_01U 1907-01-21 23:00:00    T       NaN
# ...         ...            ...                 ...  ...       ...
# 28300   Odette    AU202021_23U 2021-04-09 12:00:00    D       NaN
# 28301   Odette    AU202021_23U 2021-04-09 18:00:00    D       NaN
# 28302   Odette    AU202021_23U 2021-04-10 00:00:00    D       NaN
# 28303   Odette    AU202021_23U 2021-04-10 06:00:00    D       NaN
# 28304   Odette    AU202021_23U 2021-04-10 12:00:00    D       NaN
#
#        SURFACE_CODE  CYC_TYPE   LAT    LON  POSITION_METHOD  ...  \
# 0               1.0       NaN -13.0  146.5              NaN  ...
# 1               3.0       NaN -15.0  145.0              NaN  ...
# 2               2.0       NaN -14.0  143.0              NaN  ...
# 3               2.0       NaN -13.5  142.0              NaN  ...
# 4               4.0       NaN -15.6  141.5              NaN  ...
# ...             ...       ...   ...    ...              ...  ...
# 28300           NaN       NaN -15.8  110.9              NaN  ...
# 28301           NaN       NaN -17.1  112.2              NaN  ...
# 28302           NaN       NaN -18.9  112.8              NaN  ...
# 28303           NaN       NaN -21.0  112.8              NaN  ...
# 28304           NaN       NaN -23.5  111.9              NaN  ...
#
#        MAX_REP_SWL_PER  MAX_REP_SWL_METHOD  MAX_REP_SWL_LON  MAX_REP_SWL_LAT  \
# 0                  NaN                 NaN              NaN              NaN
# 1                  NaN                 NaN              NaN              NaN
# 2                  NaN                 NaN              NaN              NaN
# 3                  NaN                 NaN              NaN              NaN
# 4                  NaN                 NaN              NaN              NaN
# ...                ...                 ...              ...              ...
# 28300              NaN                 NaN              NaN              NaN
# 28301              NaN                 NaN              NaN              NaN
# 28302              NaN                 NaN              NaN              NaN
# 28303              NaN                 NaN              NaN              NaN
# 28304              NaN                 NaN              NaN              NaN
#
#        MAX_REP_TIDE_ANOM  MAX_REP_TIDE_ANOM_UNCERTAINTY  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN                            NaN
# 4                    NaN                            NaN
# ...                  ...                            ...
# 28300                NaN                            NaN
# 28301                NaN                            NaN
# 28302                NaN                            NaN
# 28303                NaN                            NaN
# 28304                NaN                            NaN
#
#        MAX_REP_TIDE_ANOM_METHOD  MAX_REP_TIDE_ANOM_LON  MAX_REP_TIDE_ANOM_LAT  \
# 0                           NaN                    NaN                    NaN
# 1                           NaN                    NaN                    NaN
# 2                           NaN                    NaN                    NaN
# 3                           NaN                    NaN                    NaN
# 4                           NaN                    NaN                    NaN
# ...                         ...                    ...                    ...
# 28300                       NaN                    NaN                    NaN
# 28301                       NaN                    NaN                    NaN
# 28302                       NaN                    NaN                    NaN
# 28303                       NaN                    NaN                    NaN
# 28304                       NaN                    NaN                    NaN
#
#                                COMMENT
# 0      Imported from CYCARD; June 2009
# 1      Imported from CYCARD; June 2009
# 2      Imported from CYCARD; June 2009
# 3      Imported from CYCARD; June 2009
# 4      Imported from CYCARD; June 2009
# ...                                ...
# 28300                              NaN
# 28301                              NaN
# 28302                              NaN
# 28303                              NaN
# 28304                              NaN
#
# [28305 rows x 79 columns]

# %%
data_ml = data[["NAME","TM", "TYPE","DATA_SRC", "SURFACE_CODE", "CYC_TYPE", "LAT","LON","CENTRAL_PRES",
           "MAX_WIND_SPD","MAX_REP_WIND_DIR"]]
data_ml
# Out:
#            NAME                  TM TYPE  DATA_SRC  SURFACE_CODE  CYC_TYPE  \
# 0      unnamed  1907-01-17 23:00:00    T       NaN           1.0       NaN
# 1      unnamed  1907-01-18 23:00:00    T       NaN           3.0       NaN
# 2      unnamed  1907-01-19 23:00:00    T       NaN           2.0       NaN
# 3      unnamed  1907-01-20 23:00:00    T       NaN           2.0       NaN
# 4      unnamed  1907-01-21 23:00:00    T       NaN           4.0       NaN
# ...         ...                 ...  ...       ...           ...       ...
# 28300   Odette  2021-04-09 12:00:00    D       NaN           NaN       NaN
# 28301   Odette  2021-04-09 18:00:00    D       NaN           NaN       NaN
# 28302   Odette  2021-04-10 00:00:00    D       NaN           NaN       NaN
# 28303   Odette  2021-04-10 06:00:00    D       NaN           NaN       NaN
# 28304   Odette  2021-04-10 12:00:00    D       NaN           NaN       NaN
#
#         LAT    LON  CENTRAL_PRES  MAX_WIND_SPD  MAX_REP_WIND_DIR
# 0     -13.0  146.5         994.0           NaN               NaN
# 1     -15.0  145.0         993.0           NaN               NaN
# 2     -14.0  143.0         993.0           NaN               NaN
# 3     -13.5  142.0         993.0           NaN               NaN
# 4     -15.6  141.5         998.0           NaN               NaN
# ...     ...    ...           ...           ...               ...
# 28300 -15.8  110.9         990.0          20.6               NaN
# 28301 -17.1  112.2         990.0          20.6               NaN
# 28302 -18.9  112.8         992.0          20.6               NaN
# 28303 -21.0  112.8         994.0          18.0               NaN
# 28304 -23.5  111.9         994.0          15.4               NaN
#
# [28305 rows x 11 columns]

# %%
data_ml.isna().sum()
# Out:
# NAME                    6
# TM                      6
# TYPE                    6
# DATA_SRC             9016
# SURFACE_CODE         2183
# CYC_TYPE             9825
# LAT                     6
# LON                     6
# CENTRAL_PRES         2586
# MAX_WIND_SPD         8420
# MAX_REP_WIND_DIR    24094
# dtype: int64

# %%
data_ml = data_ml.dropna()
data_ml.shape
# Out:
# (1692, 11)

# %%
data_ml["NAME"]=data_ml["NAME"].apply(lambda x: x.strip().title())
data_ml
# Out:
# C:\Users\Lites\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          NAME                  TM TYPE  DATA_SRC  SURFACE_CODE  CYC_TYPE  \
# 6544   Althea 1971-12-23 23:00:00    T       4.0           3.0      40.0
# 8143    Annie 1973-11-22 06:00:00    T       2.0           1.0      20.0
# 8145    Annie 1973-11-22 12:00:00    T       2.0           1.0      20.0
# 8149    Annie 1973-11-23 00:01:00    T       2.0           1.0      20.0
# 8151    Annie 1973-11-23 06:00:00    T       2.0           1.0      20.0
# ...       ...                 ...  ...       ...           ...       ...
# 22830  George 2007-03-04 18:00:00    T       3.0           2.0      30.0
# 24330  Carlos 2011-02-15 12:00:00    T       3.0           4.0      21.0
# 24335  Carlos 2011-02-15 21:00:00    T       3.0           2.0      30.0
# 24338  Carlos 2011-02-16 00:00:00    T       3.0           2.0      30.0
# 24347  Carlos 2011-02-16 09:00:00    T       3.0           2.0      30.0
#
#          LAT     LON  CENTRAL_PRES  MAX_WIND_SPD  MAX_REP_WIND_DIR
# 6544  -19.00  146.40         952.0          46.3             120.0
# 8143  -11.00   92.60        1001.0          12.9             100.0
# 8145  -11.10   93.10        1002.0          12.9             110.0
# 8149  -11.10   94.20        1003.0          12.9             160.0
# 8151  -11.10   94.60        1000.0          12.9             210.0
# ...      ...     ...           ...           ...               ...
# 22830 -14.30  126.40         986.0          20.6             270.0
# 24330 -12.73  130.61         999.0          20.6             350.0
# 24335 -12.54  130.72         993.0          18.0             210.0
# 24338 -12.41  130.99         995.0          18.0             210.0
# 24347 -12.54  130.98         994.0          20.6             220.0
#
# [1692 rows x 11 columns]
